# %% [markdown]
# # 2 Object-Oriented Design for Implemetnation

# %% [markdown]
# 1. Module
# 2. DataModule
# 3. Trainer

# %%
import time
import numpy as np
import torch
from torch import nn
from d2l import torch as d2l

# %%
def add_to_class(Class):
    def wrapper(obj):
        setattr(Class, obj.__name__, obj)
    return wrapper
